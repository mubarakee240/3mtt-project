# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy import stats

# %%
df = pd.read_csv('Multiple.csv')
print ("data shape:", df.shape)
print (df.head())
# Out:
# data shape: (572, 5)
#        TV      Radio  Social Media Influencer       Sales
# 0     Low   3.518070      2.293790      Micro   55.261284
# 1     Low   7.756876      2.572287       Mega   67.574904
# 2    High  20.348988      1.227180      Micro  272.250108
# 3  Medium  20.108487      2.728374       Mega  195.102176
# 4    High  31.653200      7.776978       Nano  273.960377

# %%
print (df.columns)
# Out:
# Index(['TV', 'Radio', 'Social Media', 'Influencer', 'Sales'], dtype='str')

# %%
print (df.isnull().sum())
# Out:
# TV              0
# Radio           0
# Social Media    0
# Influencer      0
# Sales           0
# dtype: int64

# %%
df = df.fillna(0)
print ("missing values handled. shape:", df.shape)
# Out:
# missing values handled. shape: (572, 5)

# %%
print (df.dtypes)
# Out:
# TV                  str
# Radio           float64
# Social Media    float64
# Influencer          str
# Sales           float64
# dtype: object

# %%
df = pd.get_dummies(df, columns=['Influencer'], drop_first=True)
print(df.head())
# Out:
#        TV      Radio  Social Media       Sales  Influencer_Mega  \
# 0     Low   3.518070      2.293790   55.261284            False
# 1     Low   7.756876      2.572287   67.574904             True
# 2    High  20.348988      1.227180  272.250108            False
# 3  Medium  20.108487      2.728374  195.102176             True
# 4    High  31.653200      7.776978  273.960377            False
#
#    Influencer_Micro  Influencer_Nano
# 0              True            False
# 1             False            False
# 2              True            False
# 3             False            False
# 4             False             True

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlations = numeric_df.corr()['Sales'].sort_values(ascending=False)
print ("Correlation with Sales:")
print (correlations)
# Out:
# Correlation with Sales:
# Sales           1.000000
# Radio           0.858036
# Social Media    0.542048
# Name: Sales, dtype: float64

# %%
X_corr = numeric_df.drop(columns=['Sales'])
corr_matrix = X_corr.corr()
print ("Correlation matrix of predictors:")
print (corr_matrix)

print ("\nhigh correlations between predictors (>0.7):")
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        col1 = corr_matrix.columns[i]
        col2 = corr_matrix.columns[j]
        val = corr_matrix.iloc[i, j]
        if abs(val) > 0.7:
            print(col1, "and", col2, ":", round(val, 3))
# Out:
# Correlation matrix of predictors:
#                  Radio  Social Media
# Radio         1.000000      0.629941
# Social Media  0.629941      1.000000
#
# high correlations between predictors (>0.7):
